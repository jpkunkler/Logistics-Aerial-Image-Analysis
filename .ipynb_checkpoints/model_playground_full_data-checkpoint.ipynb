# %%
from fastai.vision import *
from fastai.metrics import error_rate
from sklearn.model_selection import train_test_split
import numpy
import pandas as pd
import datetime
import warnings; warnings.simplefilter('ignore')

# %%
data_dir = Path("./data_dir_full")

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)
#data = ImageDataBunch.from_csv(data_dir, folder='train', size=500, suffix='.jpeg', label_delim = ' ', ds_tfms=planet_tfms)

# %%
data = (ImageList.from_folder(data_dir) #Where to find the data? -> in path and its subfolders
        .split_by_folder()              #How to split in train/valid? -> use the folders
        .label_from_folder()            #How to label? -> depending on the folder of the filenames
        .add_test_folder()              #Optionally add a test set (here default name is test)
        .transform(tfms, size=224)       #Data augmentation? -> use tfms with a size of 64
        .databunch(bs=32)
        .normalize(imagenet_stats))

# %%
data.classes
# Out:
# ['Gut', 'Mittel', 'Schlecht', 'Sehr_Gut']

# %%
data.show_batch(rows=3, figsize=(12,9))

# %%
# set up convolutional neural network (cnn) based on pre-trained resnet50 architecture
# use accuracy as metric since we are doing classification tasks on single classes
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
# inspect network architecture
learn
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (617 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Sehr_Gut,Sehr_Gut,Sehr_Gut,Sehr_Gut,Sehr_Gut
# Path: data_dir_full;
#
# Valid: LabelList (155 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Sehr_Gut,Sehr_Gut,Sehr_Gut,Sehr_Gut,Sehr_Gut
# Path: data_dir_full;
#
# Test: LabelList (193 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: EmptyLabelList
# ,,,,
# Path: data_dir_full, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
# ...

# %%
learn.fit_one_cycle(4) # run one cycle for 4 epochs using our determined learning rate to adjust output layer to our own data
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.550937</td>
#       <td>0.910598</td>
#       <td>0.316129</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.168478</td>
#       <td>0.658614</td>
#       <td>0.219355</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.941274</td>
#       <td>0.588023</td>
#       <td>0.193548</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.790035</td>
#       <td>0.560836</td>
#       <td>0.187097</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze() # must be done before calling lr_find --> we can now train all layers, not just the last one
learn.fit_one_cycle(4, max_lr=slice(1e-04, 1e-02)) # fit model again, now adjusting all layers
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.667007</td>
#       <td>1.939399</td>
#       <td>0.212903</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.666774</td>
#       <td>2.450610</td>
#       <td>0.503226</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.591308</td>
#       <td>0.451739</td>
#       <td>0.206452</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.531762</td>
#       <td>0.406074</td>
#       <td>0.167742</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_val_size = str(len(learn.data.train_ds + learn.data.valid_ds))
learn.save("model_" + str(datetime.datetime.now()) + "_" + train_val_size + "items")

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))
plt.savefig("resnet50_CAM_wrong_predictions.png", dpi=300)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
plt.savefig("confusion_matrix_resnet.png", dpi=300)

# %%
interp.most_confused(min_val=3)
# Out:
# [('Gut', 'Sehr_Gut', 13), ('Sehr_Gut', 'Gut', 6), ('Mittel', 'Gut', 5)]

# %%
learn.export()

# %%
learn.data.test_ds[7][0]
# Out:
# Image (3, 224, 224)

# %%
prediction = learn.predict(learn.data.test_ds[7][0])

# %%
from torch import topk

# %%
prob, label = topk(prediction[2],4)

# %%
prediction[0]
# Out:
# Category Sehr_Gut

# %%
# show mapping from labels to indices in our model
learn.data.c2i
# Out:
# {'Gut': 0, 'Mittel': 1, 'Schlecht': 2, 'Sehr_Gut': 3}

# %%
# reverse key/value pairs from "Gut": 0 to 0: "Gut" to later use in map function 
inv_map = {v: k for k, v in learn.data.c2i.items()}

# %%
labels = list(map(inv_map.get,label.data.tolist()))

# %%
dict(zip(labels, prob.data.tolist()))
# Out:
# {'Sehr_Gut': 0.941701352596283,
#  'Gut': 0.05411263182759285,
#  'Mittel': 0.003624966833740473,
#  'Schlecht': 0.0005609975778497756}

# %%
preds, y = learn.get_preds()
cnn_score = accuracy(preds, y).item()
print("Accuracy Score for ResNet40 = {0:.2f}".format(cnn_score))
# Out:
# Accuracy Score for ResNet40 = 0.83

# %% [markdown]
# # IMBALANCED DATA

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import matthews_corrcoef
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.pipeline import Pipeline
from PIL import Image
import numpy as np
from random import shuffle
import seaborn as sns

# %%
def load_data(directory, IMG_SIZE):
    train_data = []
    for root, dirs, files in os.walk(directory):
        path = root.split(os.sep)
        for img in files:
            label = os.path.basename(root)
            fpath = os.path.join(root, img)
            img = Image.open(fpath)
            img = img.convert('L')
            img = img.resize(IMG_SIZE, Image.ANTIALIAS)
            train_data.append([np.array(img), label])

    shuffle(train_data)
    return train_data

# %%
def augment_data(data):
    aug_data = []
    for img in data:
        # Basic Data Augmentation - Horizontal Flipping
        flip_img = Image.fromarray(img[0])
        flip_img = flip_img.convert('L')
        flip_img = np.array(flip_img)
        flip_img = np.fliplr(flip_img)
        aug_data.append([flip_img, img[1]])
        
        # Vertical Flipping
        flip_img = Image.fromarray(img[0])
        flip_img = flip_img.convert('L')
        flip_img = np.array(flip_img)
        flip_img = np.flipud(flip_img)
        aug_data.append([flip_img, img[1]])
    return data + aug_data

# %%
def reshapeImage(img):
    nx, ny = img.shape
    return img.reshape((1, nx*ny))

# %%
IMG_SIZE = (224,224)
train = load_data(data_dir/"train", IMG_SIZE)
test = load_data(data_dir/"test", IMG_SIZE)

# %%
train = augment_data(train)

# %%
def formatDataset(data):
    images = []
    labels = []
    for elem in data:
        images.append(elem[0])
        labels.append(elem[1])
    
    images = np.array(images)
    nsamples, nx, ny = images.shape
    images = images.reshape((nsamples, nx*ny))
    return images, labels

# %%
train_data, train_labels = formatDataset(train)

# %%
test_data, test_labels = formatDataset(test)

# %%
# Total Training Samples after data augmentation
len(train_data)
# Out:
# 1851

# %%
# total distribution of training labels
sns.countplot(train_labels)
plt.savefig("imbalanced.png", dpi=300)

# %% [markdown]
# ## Support Vector Machine

# %%
# we begin by normalizing the images to values between 0 and 1 using the Standard Scaler
# After that, we use a Support Vector Machine with a non-linear polynomial kernel
steps = [('scaler', StandardScaler()), ('SVM', SVC(kernel='poly'))]
pipeline = Pipeline(steps) # define Pipeline object

# %%
# We apply Grid Search to find the best hyperparameters for our SVM model
parameters = {'SVM__C':[0.001, 0.1, 100, 10e5], 'SVM__gamma':[10,1,0.1,0.01]}
grid = GridSearchCV(pipeline, param_grid=parameters, cv=5, n_jobs=-1, verbose=10)

# %%
grid.fit(train_data[:100], train_labels[:100])
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   38.8s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('SVM', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
# ...

# %%
svm_score_imb = grid.score(test_data, test_labels)
print("Accuracy Score for SVM with imbalanced data = {0:.2f}".format(svm_score_imb))
print("Parameters found = ", grid.best_params_)
# Out:
# Accuracy Score for SVM with imbalanced data = 0.73
# Parameters found =  {'SVM__C': 0.001, 'SVM__gamma': 10}

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from collections import Counter
import scipy

# %%
# highly imbalanced data set
Counter(train_labels)
# Out:
# Counter({'Gut': 381, 'Sehr_Gut': 1326, 'Mittel': 84, 'Schlecht': 60})

# %%
log_steps_imb = [('scaler', StandardScaler()), ('LogReg', LogisticRegression(solver = 'lbfgs'))]
log_pipeline_imb = Pipeline(log_steps_imb) # define Pipeline object

# %%
log_pipeline_imb.fit(train_data, train_labels)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('LogReg', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
Counter(log_pipeline_imb.predict(test_data))
# Out:
# Counter({'Sehr_Gut': 118, 'Mittel': 25, 'Gut': 37, 'Schlecht': 13})

# %%
logreg_score_imb = log_pipeline_imb.score(test_data, test_labels)
print("Accuracy score for logistic regression with imbalanced data = {0:.2f}".format(logreg_score_imb))
# Out:
# Accuracy score for logistic regression with imbalanced data = 0.54

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_steps_imb = [("scaler", StandardScaler()), ("rfc", RandomForestClassifier(n_jobs=-1, n_estimators=100))]
rfc_pipeline_imb = Pipeline(rfc_steps_imb)

# %%
rfc_pipeline_imb.fit(train_data, train_labels)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('rfc', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#      ..._jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %%
rfc_score_imb = rfc_pipeline_imb.score(test_data, test_labels)
print("Accuracy Score for Random Forest with imbalanced data = {0:.2f}".format(rfc_score_imb))
# Out:
# Accuracy Score for Random Forest with imbalanced data = 0.73

# %% [markdown]
# # BALANCED DATA USING OVERSAMPLING

# %%
from imblearn.over_sampling import SMOTE

# %%
# highly imbalanced data set
Counter(train_labels)
# Out:
# Counter({'Gut': 381, 'Sehr_Gut': 1326, 'Mittel': 84, 'Schlecht': 60})

# %%
# Use Oversampling to fix imbalance
sm = SMOTE(random_state=42)

# %%
X_res, y_res = sm.fit_resample(train_data, train_labels)

# %%
# Now our dataset looks balanced!
Counter(y_res)
# Out:
# Counter({'Gut': 1326, 'Sehr_Gut': 1326, 'Mittel': 1326, 'Schlecht': 1326})

# %%
sns.countplot(y_res)
plt.savefig("balanced.png", dpi=300)

# %% [markdown]
# ## SVM using balanced data

# %%
# we begin by normalizing the images to values between 0 and 1 using the Standard Scaler
# After that, we use a Support Vector Machine with a non-linear polynomial kernel
svm_steps_bal = [('scaler', StandardScaler()), ('SVM', SVC(kernel='poly'))]
svm_pipeline_bal = Pipeline(svm_steps_bal) # define Pipeline object

# %%
# We apply Grid Search to find the best hyperparameters for our SVM model
parameters = {'SVM__C':[0.001, 0.1, 100, 10e5], 'SVM__gamma':[10,1,0.1,0.01]}
svm_grid_bal = GridSearchCV(svm_pipeline_bal, param_grid=parameters, cv=5, n_jobs=-1, verbose=10)

# %%
svm_grid_bal.fit(X_res[:100], y_res[:100])
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:   36.8s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('SVM', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
# ...

# %%
svm_score_bal = svm_grid_bal.score(test_data, test_labels)
print("Accuracy Score for SVM with balanced data = {0:.2f}".format(svm_score_bal))
print("Parameters found = ", svm_grid_bal.best_params_)
# Out:
# Accuracy Score for SVM with balanced data = 0.73
# Parameters found =  {'SVM__C': 0.001, 'SVM__gamma': 10}

# %% [markdown]
# ## Logistic Regression using balanced data

# %%
log_steps = [('scaler', StandardScaler()), ('LogReg', LogisticRegression(solver = 'lbfgs'))]
log_pipeline = Pipeline(log_steps) # define Pipeline object

# %%
log_pipeline.fit(X_res, y_res)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('LogReg', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
Counter(log_pipeline.predict(test_data))
# Out:
# Counter({'Sehr_Gut': 159, 'Gut': 25, 'Schlecht': 4, 'Mittel': 5})

# %%
logreg_score_bal = log_pipeline.score(test_data, test_labels)
print("Accuracy score for logistic regression with balanced data = {0:.2f}".format(logreg_score_bal))
# Out:
# Accuracy score for logistic regression with balanced data = 0.68

# %% [markdown]
# ## Random Forest using balanced data

# %%
rfc_steps_bal = [("scaler", StandardScaler()), ("rfc", RandomForestClassifier(n_jobs=-1, n_estimators=100))]
rfc_pipeline_bal = Pipeline(rfc_steps_bal)

# %%
rfc_pipeline_bal.fit(X_res, y_res)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('rfc', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#      ..._jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %%
rfc_score_bal = rfc_pipeline_bal.score(test_data, test_labels)
print("Accuracy Score for Random Forest with balanced data = {0:.2f}".format(rfc_score_bal))
# Out:
# Accuracy Score for Random Forest with balanced data = 0.70

# %% [markdown]
# # Comparing model performance

# %%
import pandas as pd

# %%
fig, ax = plt.subplots(1,2, figsize=(12,7))

# color scheme
muted=["#4878CF", "#6ACC65", "#D65F5F",
           "#B47CC7", "#C4AD66", "#77BEDB"]
# set specific color for each model
newPal   = dict(ResNet50 = muted[0], SVM = muted[2], LogReg = muted[1], RFC = muted[3])

models = ["ResNet50", "LogReg", "RFC", "SVM"]
performance = [cnn_score, logreg_score_imb, rfc_score_imb, svm_score_imb]
data = {"model":models, "accuracy":performance}
df = pd.DataFrame(data)
df.sort_values(by="accuracy", ascending=False, inplace=True)
splot = sns.barplot(x="model", y="accuracy", data=df, ax=ax[0], palette=newPal)

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    
splot.set_title("Imbalanced Data")

models = ["ResNet50", "LogReg", "RFC", "SVM"]
performance = [cnn_score, logreg_score_bal, rfc_score_bal, svm_score_bal]
data = {"model":models, "accuracy":performance}
df = pd.DataFrame(data)
df.sort_values(by="accuracy", ascending=False, inplace=True)
splot = sns.barplot(x="model", y="accuracy", data=df, ax=ax[1], palette=newPal)

for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    
splot.set_title("Balanced Data")

fig.suptitle("Comparison of Model Performance for Imbalanced versus Balanced Dataset", size=16)
fig.show()
plt.savefig("comparison.png",dpi=900)
